# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdelrhman129/my-_colab_notbook/blob/main/Data_Anlalysis_Phython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Analysis with Python: Part 1 of 6

# %% [markdown]
# **Part_one(frist_video)**

# %%
2+3+9
# Out:
# 14

# %%
99-73
# Out:
# 26

# %%
23.54 * -1432
# Out:
# -33709.28

# %%
100/7
# Out:
# 14.285714285714286

# %%
100//7
# Out:
# 14

# %%
100 % 7
# Out:
# 2

# %%
5 ** 3
# Out:
# 125

# %%
((2+5)*(17-3))/(4**3)
# Out:
# 1.53125

# %% [markdown]
# Python supports the following arithmetic operators:
#
# | Operator   | Purpose           | Example     | Result    |
# |------------|-------------------|-------------|-----------|
# | `+`        | Addition          | `2 + 3`     | `5`       |
# | `-`        | Subtraction       | `3 - 2`     | `1`       |
# | `*`        | Multiplication    | `8 * 12`    | `96`      |
# | `/`        | Division          | `100 / 7`   | `14.28..` |
# | `//`       | Floor Division    | `100 // 7`  | `14`      |
# | `%`        | Modulus/Remainder | `100 % 7`   | `2`       |
# | `**`       | Exponent          | `5 ** 3`    | `125`     |
#
#
# Try solving some simple problems from this page: https://www.math-only-math.com/worksheet-on-word-problems-on-four-operations.html . You can use the empty cells below and add more cells if required.

# %% [markdown]
# [ ]
# Solving multi-step problems using variables
# Let's try solving the following word problem using Python:
#
# A grocery store sells a bag of ice for $1.25, and makes 20% profit. If it sells 500 bags of ice, how much total profit does it make?
#
# We can list out the information provided, and gradually convert the word problem into a mathematical expression which can be evaluated using Python.
#
# Cost of ice bag ($) = 1.25
#
# Profit margin = 20% = .2
#
# Profit per bag ($) = profit margin * cost of ice bag = .2 * 1.25
#
# No. of bags = 500
#
# Total profit = no. of bags * profit per bag = 500 * (.2 * 1.25)

# %%
500*(1.25*2)
# Out:
# 1250.0

# %%
cost_of_ice_bag = 1.25

# %%
profit_margin = .2

# %%
number_of_bags = 500

# %%
profit_margin
# Out:
# 0.2

# %%
profit_per_bag = cost_of_ice_bag * profit_margin

# %%
total_profit = number_of_bags * profit_per_bag

# %%
total_profit
# Out:
# 125.0

# %%
print("The grocery store makes a total profit of $",total_profit)
# Out:
# The grocery store makes a total profit of $ 125.0

# %%
# Store input data in variables
cost_of_ice_bag = 1.25
profit_margin = .2
number_of_bags = 500

# Perform the required calculations
profit_per_bag = cost_of_ice_bag * profit_margin
total_profit = number_of_bags * profit_per_bag

# Display the result
print("The grocery store makes a total profit of $", total_profit)
# Out:
# The grocery store makes a total profit of $ 125.0

# %% [markdown]
# Evaluating conditions using Python
# Apart from arithmetic operations, Python also provides several oprations for comparing numbers & variables.
#
# Operator	Description
# ==	Check if operands are equal
# !=	Check if operands are not equal
# >	Check if left operand is greater than right operand
# <	Check if left operand is less than right operand
# >=	Check if left operand is greater than or equal to right operand
# <=	Check if left operand is less than or equal to right operand
# The result of a comparision operation is either True or False (note the uppercase T and F). These are special keywords in Python. Let's try out some experiment with comparision operators.

# %%
my_favorite_number = 1
my_least_favorite_number = 5
a_neutral_number = 3

# %%
# Equality check_True
my_favorite_number == 1
# Out:
# True

# %%
# Equality check - False
my_favorite_number == my_least_favorite_number
# Out:
# False

# %%
# Not equal check - True
my_favorite_number != a_neutral_number
# Out:
# True

# %%
# Not equal check - False
a_neutral_number != 3
# Out:
# False

# %%
# Greater than check - True
my_least_favorite_number > a_neutral_number
# Out:
# True

# %%
cost_of_ice_bag = 1.25
is_ice_bag_expensive = cost_of_ice_bag >=10
print("Is the ice bag expensive?", is_ice_bag_expensive)
# Out:
# Is the ice bag expensive? False

# %% [markdown]
# ## Combining conditions with logical operators
#
# The logical operators `and`, `or` and `not` operate upon conditions and `True` & `False` values (also known as *booleans*). `and` and `or` operate on two conditions, whereas `not` operates on a single condition.
#
# The `and` operator returns `True` when both the conditions evalute to `True`. Otherwise it returns `False`.
#
# | `a`     | `b`    | `a and b` |
# |---------|--------|-----------|
# |  `True` | `True` | `True`    |
# |  `True` | `False`| `False`   |
# |  `False`| `True` | `False`   |
# |  `False`| `False`| `False`   |

# %%
my_favorite_number
# Out:
# 1

# %%
my_favorite_number >0 and my_favorite_number <=3
# Out:
# True

# %%
my_favorite_number <0 and my_favorite_number <=3
# Out:
# False

# %%
my_favorite_number >0 and my_favorite_number >=3
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %% [markdown]
# The `or` operator returns `True` if at least one of the conditions evalute to `True`. It returns `False` only if both conditions are `False`.
#
# | `a`     | `b`    | `a or b`  |
# |---------|--------|-----------|
# |  `True` | `True` | `True`    |
# |  `True` | `False`| `True`    |
# |  `False`| `True` | `True`    |
# |  `False`| `False`| `False`   |

# %%
a_neutral_number
# Out:
# 3

# %%
a_neutral_number == 3 or my_favorite_number < 0
# Out:
# True

# %%
a_neutral_number != 3 or my_favorite_number < 0
# Out:
# False

# %%
my_favorite_number < 0 or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not a_neutral_number ==3
# Out:
# False

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %% [markdown]
# Logical operators can be combined to form complex conditions. Use round brackets or parantheses ( and ) to indicate the order in which logical operators should be applied.

# %%
(2>3 and 4<=5) or not (my_favorite_number <0 and True)
# Out:
# True

# %%
not (True and 0 < 1) or (False and True)
# Out:
# False

# %%
not True and 0 < 1 or False and True
# Out:
# False

# %% [markdown]
# # A Quick Tour of Variables and Data Types in Python
#
# ![](https://i.imgur.com/6cg2E9Q.png)
#
#
# This tutorial series is a beginner-friendly introduction to programming and data analysis using the Python programming language. These tutorials take a practical and coding-focused approach. The best way to learn the material is to execute the code and experiment with it yourself.

# %%
my_favorite_color="blue"

# %%
my_favorite_color
# Out:
# 'blue'

# %%
color1,color2,color3 ="red","blue","Black"

# %%
color1
# Out:
# 'red'

# %%
color2
# Out:
# 'blue'

# %%
counter=10

# %%
counter+5
# Out:
# 15

# %%
counter=10

# %%
counter+=3

# %%
counter
# Out:
# 13

# %%
a_variable=21
is_today_suterday=False
my_favorite_car="Delorean"
the_3_musketeers=["Athos","porthos","Armais"]

# %%
type(a_variable)
# Out:
# int

# %%
type(is_today_suterday)
# Out:
# bool

# %% [markdown]
# Python has several built-in data types for storing different kinds of information in variables. Following are some commonly used data types:
#
# 1. Integer
# 2. Float
# 3. Boolean
# 4. None
# 5. String
# 6. List
# 7. Tuple
# 8. Dictionary
#
# Integer, float, boolean, None, and string are *primitive data types* because they represent a single value. Other data types like list, tuple, and dictionary are often called *data structures* or *containers* because they hold multiple pieces of data together.

# %%
str(23)
# Out:
# '23'

# %%
fruits = ['apple', 'banana', 'cherry']

# %%
print("the number of fruits",len(fruits))
# Out:
# the number of fruits 3

# %%
fruits.append('dates')

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'dates']

# %%
fruits[1]="bllueberry"

# %%
fruits
# Out:
# ['apple', 'bllueberry', 'cherry', 'dates']

# %%
fruits.insert(1,'banana')

# %%
fruits
# Out:
# ['apple', 'banana', 'bllueberry', 'cherry', 'dates']

# %%
fruits.pop(1)
# Out:
# 'banana'

# %%
fruits
# Out:
# ['apple', 'bllueberry', 'cherry', 'dates']

# %%
fruits.pop()
# Out:
# 'dates'

# %%
fruits
# Out:
# ['apple', 'bllueberry', 'cherry']

# %% [markdown]
# ### Dictionary
#
# A dictionary is an unordered collection of items. Each item stored in a dictionary has a key and value. You can use a key to retrieve the corresponding value from the dictionary.  Dictionaries have the type `dict`.
#
# Dictionaries are often used to store many pieces of information e.g. details about a person, in a single variable. Dictionaries are created by enclosing key-value pairs within braces or curly brackets `{` and `}`.

# %%
personl={
    "name":'Abdelrahman',
    'sex':'Male',
    'age':'24',
    'married':True

}

# %%
personl
# Out:
# {'name': 'Abdelrahman', 'sex': 'Male', 'age': '24', 'married': True}

# %%
personl2=dict(name='Ahmed',sex='Male',age='12',married=False)

# %%
personl2
# Out:
# {'name': 'Ahmed', 'sex': 'Male', 'age': '12', 'married': False}

# %%
type(personl)
# Out:
# dict

# %%
personl["name"]
# Out:
# 'Abdelrahman'

# %%
"addries" in personl2
# Out:
# False

# %%
"name" in personl2
# Out:
# True

# %% [markdown]
# # NUMPY

# %%
w1 ,w2 ,w3 =0.3,0.2,0.5

# %%
kanto_temp=73
kanto_rainfall=67
kanto_humidity=43

# %%
kanto_yeild_apples=kanto_temp*w1+kanto_rainfall*w2+kanto_humidity*w3

# %%
print("the expected yeild of apple in kanto region is {} tons per hectare".format(kanto_yeild_apples))
# Out:
# the expected yeild of apple in kanto region is 56.8 tons per hectare

# %%
kanto=[73,67,43]
johto=[91,88,64]
hoenn=[87,134,58]
sinnoh=[102,43,37]
unova=[69,96,70]

# %%
wieghts=[w1,w2,w3]

# %%
def crop_yield(region,wieghts):
  result=0
  for x,w in zip(region,wieghts):
    result+=x*w
  return result

# %%
crop_yield(kanto,wieghts)
# Out:
# 56.8

# %%
crop_yield(johto,wieghts)
# Out:
# 76.9

# %%
crop_yield(hoenn,wieghts)
# Out:
# 81.9

# %%
crop_yield(sinnoh,wieghts)
# Out:
# 57.699999999999996

# %%
import numpy as np

# %%
kanto=np.array([79,67,43])

# %%
kanto
# Out:
# array([79, 67, 43])

# %%
wieghts=np.array([w1,w2,w3])

# %%
wieghts
# Out:
# array([0.3, 0.2, 0.5])

# %%
type(kanto)
# Out:
# numpy.ndarray

# %%
np.dot(kanto,wieghts)
# Out:
# np.float64(58.6)

# %%
(kanto*wieghts).sum()
# Out:
# np.float64(58.6)

# %%
arr1=np.array([1,2,3])
arr2=np.array([4,5,6])

# %%
arr1*arr2
# Out:
# array([ 4, 10, 18])

# %%
arr2.sum()
# Out:
# np.int64(15)

# %%
wieghts
# Out:
# array([0.3, 0.2, 0.5])

# %%
climate_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_42338/492441351.py in <cell line: 0>()
# ----> 1 climate_data
#
# NameError: name 'climate_data' is not defined

# %%
climate_data=np.array([[73,67,43],
                      [91,88,64],
                      [87,134,58],
                      [102,43,37],
                      [69,96,70]])

# %%
climate_data

# %%
climate_data.shape

# %%
type(climate_data)

# %%
climate_data.shape

# %%
wieghts.shape

# %%
arr3=np.array([
    [[11,12,13],
     [13,14,15]],
    [[15,16,17],
     [17,18,19.5]]])

# %%
arr3.shape

# %%
print(arr3.shape)

# %%
climate_data.dtype

# %%
np.dot(climate_data,wieghts)

# %%
import pandas as pd

# %%
df = pd.read_csv("countries of the world.csv")
df

# %%
df = pd.read_csv("countries of the world.csv",header=None)
df

# %%
df = pd.read_csv("countries of the world.csv",header=None,names=['country','region'])
df

# %%
df=pd.read_csv("countries of the world (2).txt")
df

# %%
df=pd.read_table("countries of the world (2).txt",sep='\t')

df

# %%
df=pd.read_json("json_sample.json")
df

# %%
df2=pd.read_excel("world_population_excel_workbook.xlsx",sheet_name='world_population')
df2

# %%
df2.shape

# %%
pd.set_option('display.max.rows',236)
pd.set_option('display.max.columns',40)

# %%
df2.info()

# %%
pd.reset_option('display.max.rows')
pd.reset_option('display.max.columns')

# %%
df2.head()

# %%
df2.tail()

# %%
df2['Rank']

# %%
df2['Continent']

# %%
df2.loc[233]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_42338/2039817168.py in <cell line: 0>()
# ----> 1 df2.loc[233]
#
# NameError: name 'df2' is not defined

# %%
df2.iloc[233]

# %%
df3=pd.read_csv("world_population.csv")
df3

# %%
df3[df3['Rank']<10]

# %%
specific_countries=['Bangladesh','Brazil']
df3[df3['Country'].isin(specific_countries)]

# %%
df3[df3['Country'].str.contains('Brazil')]

# %%
df=df3.set_index('Country')
df

# %%
df.filter(items=['Continent','CCA3'],axis=1)

# %%
df.filter(items=['Zimbabwe'],axis=0)

# %%
df.filter(like='United',axis=0)

# %%
df.loc['United States']

# %%
df.iloc[3]
# Out:
# First_Name                                          Dwight
# Last_Name                                          Schrute
# Phone_Number                                    1235432345
# Address              980 Paper Avenue, Pennsylvania, 18503
# Paying Customer                                        Yes
# Do_Not_Contact                                           Y
# Not_Useful_Column                                     True
# Name: 1004, dtype: object

# %%
df
# Out:
#            First_Name   Last_Name Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins   1235455421
# 1002             Abed       Nadir   1236439775
# 1003           Walter       White
# 1004           Dwight     Schrute   1235432345
# 1005              Jon        Snow   8766783469
# 1006              Ron     Swanson   3047622467
# 1007             Jeff      Winger
# 1008         Sherlock      Holmes   8766783469
# 1009          Gandalf         NaN
# 1010            Peter      Parker   1235455421
# 1011          Samwise      Gamgee
# 1012            Harry      Potter
# 1013              Don      Draper   1235432345
# 1014           Leslie       Knope   8766783469
# 1015             Toby  Flenderson   3047622467
# 1016              Ron     Weasley   1235455421
# 1017         Michael        Scott   1236439775
# 1018            Clark        Kent
# 1019            Creed      Braton
# 1020           Anakin   Skywalker   8766783469
# ...

# %%
df[df['Rank']<10].sort_values(by='Rank',ascending=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rank'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_42338/4271303940.py in <cell line: 0>()
# ----> 1 df[df['Rank']<10].sort_values(by='Rank',ascending=True)
#
# ...

# %%
 df[df['Rank']<10].sort_values(by=['Continent','Country'],ascending=False)

# %%
 df[df['Rank']<10].sort_values(by=['Continent','Country'],ascending=[False,True])

# %%
import pandas as pd

# %%
df=pd.read_csv("Flavors.csv")
df

# %%
group_by_frame = df.groupby('Base Flavor')

# %%
group_by_frame.mean(numeric_only=True)

# %%
df.groupby('Base Flavor').count()

# %%
df.groupby('Base Flavor').min()

# %%
df.groupby('Base Flavor').max()

# %%
df.groupby('Base Flavor').sum(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_42338/802495608.py in <cell line: 0>()
# ----> 1 df.groupby('Base Flavor').sum(numeric_only=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# ...

# %%
df.groupby("Base Flavor").agg({'Flavor Rating':['mean','max','min','count','sum']})

# %%
df.groupby("Base Flavor").agg({'Flavor Rating':['mean','max','min','count','sum'],'Total Rating':['mean','max','min','count','sum']})
#

# %%
df.groupby(['Base Flavor','Liked']).mean(numeric_only=True)

# %%
df.groupby(['Base Flavor','Liked']).agg({'Flavor Rating':['mean','max','min','count','sum']})
#

# %%
df.groupby("Base Flavor").describe()

# %% [markdown]
# **🧠 أهم حاجة تتعلمها هنا
# 1️⃣ مش بس تبص على mean ❌
#
# لازم تبص على:
#
# min / max
# quartiles**

# %% [markdown]
# **2️⃣ الفرق بين 25% و 75%
#
# 👉 لو الفرق صغير → الداتا ثابتة
# 👉 لو كبير → فيه تشتت**

# %%
df2=pd.read_csv("LOTR 2.csv")
df2

# %%
df1=pd.read_csv("LOTR.csv")
df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_42338/224217060.py in <cell line: 0>()
# ----> 1 df1=pd.read_csv("LOTR.csv")
#       2 df1
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
df1.merge(df2)

# %%
df1.merge(df2,how='inner')

# %%
df1.merge(df2,how='inner',on='FellowshipID')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_42338/1107911894.py in <cell line: 0>()
# ----> 1 df1.merge(df2,how='inner',on='FellowshipID')
#
# NameError: name 'df1' is not defined

# %%
df1.merge(df2,how='inner',on='FirstName')

# %%
df1.merge(df2,how='inner',on=['FirstName','FellowshipID'])

# %%
df1.merge(df2,how='outer')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_42338/38939349.py in <cell line: 0>()
# ----> 1 df1.merge(df2,how='outer')
#
# NameError: name 'df1' is not defined

# %%
df1.merge(df2,how='left')

# %%
df1.merge(df2,how='right')

# %%
df1.merge(df2,how='cross')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_42338/1802410629.py in <cell line: 0>()
# ----> 1 df1.merge(df2,how='cross')
#
# NameError: name 'df1' is not defined

# %%
df1.join(df2,on='FellowshipID',how='outer',lsuffix='_Left',rsuffix='_Right')

# %%
df4 = df1.set_index('FellowshipID').join(df2.set_index('FellowshipID'), lsuffix = '_Left',rsuffix = '_Right', how = 'outer')
df4

# %%
pd.concat([df1,df2], join = 'outer', axis = 1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Ice Cream Ratings (1).csv")
df

# %%
df=df.set_index('Date')
df

# %%
df.groupby('Date').describe()

# %%
df.plot ()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_42338/3305342606.py in <cell line: 0>()
# ----> 1 df.plot ()
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1028                     data.columns = label_name
#    1029
# -> 1030         return plot_backend.plot(data, kind=kind, **kwargs)
#    1031
#    1032     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     497     @final
# ...

# %%
df.plot(kind='bar',stacked=True)

# %%
df.plot(kind='line',title='Ice Cream Ratings',grid=True,xlabel="Daily Rating",ylabel="Rating")

# %%
df.plot(kind='hist')

# %%
df['Flavor Rating'].plot(kind='bar',stacked=True)

# %%
df.boxplot()

# %%
df.plot.area()

# %%
df.plot.bar()

# %%
df.plot.pie(y='Flavor Rating',figsize=(10,6))

# %%
import pandas as pd

# %%
df=pd.read_excel("Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
pd.set_option('display.max.columns',200)
pd.set_option("display.max.rows",200)

# %%
df=df.set_index('CustomerID')
df
# Out:
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# 1006              Ron      Swanson  304-762-2467
# 1007             Jeff       Winger           NaN
# 1008         Sherlock       Holmes  876|678|3469
# 1009          Gandalf          NaN           N/a
# 1010            Peter       Parker  123-545-5421
# 1011          Samwise       Gamgee           NaN
# 1012            Harry    ...Potter    7066950392
# 1013              Don       Draper  123-543-2345
# 1014           Leslie        Knope  876|678|3469
# 1015             Toby  Flenderson_  304-762-2467
# 1016              Ron      Weasley  123-545-5421
# 1017         Michael         Scott  123/643/9775
# 1018            Clark         Kent    7066950392
# ...

# %%
df.drop_duplicates()
# Out:
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# 1006              Ron      Swanson  304-762-2467
# 1007             Jeff       Winger           NaN
# 1008         Sherlock       Holmes  876|678|3469
# 1009          Gandalf          NaN           N/a
# 1010            Peter       Parker  123-545-5421
# 1011          Samwise       Gamgee           NaN
# 1012            Harry    ...Potter    7066950392
# 1013              Don       Draper  123-543-2345
# 1014           Leslie        Knope  876|678|3469
# 1015             Toby  Flenderson_  304-762-2467
# 1016              Ron      Weasley  123-545-5421
# 1017         Michael         Scott  123/643/9775
# 1018            Clark         Kent    7066950392
# ...

# %%
df.drop(columns='Not_Useful_Column')
# Out:
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# 1006              Ron      Swanson  304-762-2467
# 1007             Jeff       Winger           NaN
# 1008         Sherlock       Holmes  876|678|3469
# 1009          Gandalf          NaN           N/a
# 1010            Peter       Parker  123-545-5421
# 1011          Samwise       Gamgee           NaN
# 1012            Harry    ...Potter    7066950392
# 1013              Don       Draper  123-543-2345
# 1014           Leslie        Knope  876|678|3469
# 1015             Toby  Flenderson_  304-762-2467
# 1016              Ron      Weasley  123-545-5421
# 1017         Michael         Scott  123/643/9775
# 1018            Clark         Kent    7066950392
# ...

# %%
df['Last_Name']=df['Last_Name'].str.lstrip('/')
df['Last_Name']=df['Last_Name'].str.rstrip('_')
df['Last_Name']=df['Last_Name'].str.rstrip('...')


df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123/643/9775
# 1003           Walter       White    7066950392
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876|678|3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger           NaN
# 1008         Sherlock      Holmes  876|678|3469
# 1009          Gandalf         NaN           N/a
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee           NaN
# 1012            Harry   ...Potter    7066950392
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876|678|3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123/643/9775
# 1018            Clark        Kent    7066950392
# ...

# %%
df['Last_Name']=df['Last_Name'].str.strip('123._/')
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123/643/9775
# 1003           Walter       White    7066950392
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876|678|3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger           NaN
# 1008         Sherlock      Holmes  876|678|3469
# 1009          Gandalf         NaN           N/a
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee           NaN
# 1012            Harry      Potter    7066950392
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876|678|3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123/643/9775
# 1018            Clark        Kent    7066950392
# ...

# %%
df['Last_Name']
# Out:
# CustomerID
# 1001       Baggins
# 1002         Nadir
# 1003         White
# 1004       Schrute
# 1005          Snow
# 1006       Swanson
# 1007        Winger
# 1008        Holmes
# 1009           NaN
# 1010        Parker
# 1011        Gamgee
# 1012        Potter
# 1013        Draper
# 1014         Knope
# 1015    Flenderson
# 1016       Weasley
# 1017         Scott
# 1018          Kent
# 1019        Braton
# 1020     Skywalker
# 1020     Skywalker
# Name: Last_Name, dtype: object

# %%
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123/643/9775
# 1003           Walter       White    7066950392
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876|678|3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger           NaN
# 1008         Sherlock      Holmes  876|678|3469
# 1009          Gandalf         NaN           N/a
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee           NaN
# 1012            Harry      Potter    7066950392
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876|678|3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123/643/9775
# 1018            Clark        Kent    7066950392
# ...

# %%
df['Phone_Number'].str.replace("[^a-zA-z0-9]",' ')
# Out:
# CustomerID
# 1001    123-545-5421
# 1002    123/643/9775
# 1003             NaN
# 1004    123-543-2345
# 1005    876|678|3469
# 1006    304-762-2467
# 1007             NaN
# 1008    876|678|3469
# 1009             N/a
# 1010    123-545-5421
# 1011             NaN
# 1012             NaN
# 1013    123-543-2345
# 1014    876|678|3469
# 1015    304-762-2467
# 1016    123-545-5421
# 1017    123/643/9775
# 1018             NaN
# 1019             N/a
# 1020    876|678|3469
# 1020    876|678|3469
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number']=df['Phone_Number'].str.replace("[^a-zA-Z0-9]", '', regex=True)
df
# Out:
#            First_Name   Last_Name Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins   1235455421
# 1002             Abed       Nadir   1236439775
# 1003           Walter       White          NaN
# 1004           Dwight     Schrute   1235432345
# 1005              Jon        Snow   8766783469
# 1006              Ron     Swanson   3047622467
# 1007             Jeff      Winger          NaN
# 1008         Sherlock      Holmes   8766783469
# 1009          Gandalf         NaN           Na
# 1010            Peter      Parker   1235455421
# 1011          Samwise      Gamgee          NaN
# 1012            Harry      Potter          NaN
# 1013              Don      Draper   1235432345
# 1014           Leslie       Knope   8766783469
# 1015             Toby  Flenderson   3047622467
# 1016              Ron     Weasley   1235455421
# 1017         Michael        Scott   1236439775
# 1018            Clark        Kent          NaN
# 1019            Creed      Braton           Na
# ...

# %%
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123/643/9775
# 1003           Walter       White    7066950392
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876|678|3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger           NaN
# 1008         Sherlock      Holmes  876|678|3469
# 1009          Gandalf         NaN           N/a
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee           NaN
# 1012            Harry      Potter    7066950392
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876|678|3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123/643/9775
# 1018            Clark        Kent    7066950392
# ...

# %%
import numpy as np

df['Phone_Number'] = df['Phone_Number'].astype(str)

# نشيل أي حاجة غير الأرقام
df['Phone_Number'] = df['Phone_Number'].str.replace(r'[^0-9]', '', regex=True)

# نخلي الرقم اللي طوله مش 10 يبقى NaN
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x if len(x)==10 else np.nan)

# نعمل فورمات 123-456-7890
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[0:3]+'-'+x[3:6]+'-'+x[6:10] if pd.notna(x) else np.nan)

# %%
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123-643-9775
# 1003           Walter       White  706-695-0392
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876-678-3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger           NaN
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf         NaN           NaN
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee           NaN
# 1012            Harry      Potter  706-695-0392
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent  706-695-0392
# ...

# %%
df['Phone_Number'].str.replace('NaN','')
# Out:
# CustomerID
# 1001    123-545-5421
# 1002    123-643-9775
# 1003             NaN
# 1004    123-543-2345
# 1005    876-678-3469
# 1006    304-762-2467
# 1007             NaN
# 1008    876-678-3469
# 1009             NaN
# 1010    123-545-5421
# 1011             NaN
# 1012             NaN
# 1013    123-543-2345
# 1014    876-678-3469
# 1015    304-762-2467
# 1016    123-545-5421
# 1017    123-643-9775
# 1018             NaN
# 1019             NaN
# 1020    876-678-3469
# 1020    876-678-3469
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number']=df['Phone_Number'].fillna('')
df

# %%
df['Address']
# Out:
# CustomerID
# 1001                    123 Shire Lane, Shire
# 1002                      93 West Main Street
# 1003                       298 Drugs Driveway
# 1004    980 Paper Avenue, Pennsylvania, 18503
# 1005                         123 Dragons Road
# 1006                         768 City Parkway
# 1007                        1209 South Street
# 1008                            98 Clue Drive
# 1009                         123 Middle Earth
# 1010               25th Main Street, New York
# 1011                    612 Shire Lane, Shire
# 1012                     2394 Hogwarts Avenue
# 1013                         2039 Main Street
# 1014                         343 City Parkway
# 1015                            214 HR Avenue
# 1016                     2395 Hogwarts Avenue
# 1017           121 Paper Avenue, Pennsylvania
# 1018                          3498 Super Lane
# 1019                                      N/a
# 1020              910 Tatooine Road, Tatooine
# ...

# %%
df['Address'].str.split(',',n=1,expand=True)
# Out:
#                                0                     1
# CustomerID
# 1001              123 Shire Lane                 Shire
# 1002         93 West Main Street                  None
# 1003          298 Drugs Driveway                  None
# 1004            980 Paper Avenue   Pennsylvania, 18503
# 1005            123 Dragons Road                  None
# 1006            768 City Parkway                  None
# 1007           1209 South Street                  None
# 1008               98 Clue Drive                  None
# 1009            123 Middle Earth                  None
# 1010            25th Main Street              New York
# 1011              612 Shire Lane                 Shire
# 1012        2394 Hogwarts Avenue                  None
# 1013            2039 Main Street                  None
# 1014            343 City Parkway                  None
# 1015               214 HR Avenue                  None
# 1016        2395 Hogwarts Avenue                  None
# ...

# %%
df['Address'].str.split(pat=',', n=2, expand=True)
# Out:
#                                0              1       2
# CustomerID
# 1001              123 Shire Lane          Shire    None
# 1002         93 West Main Street           None    None
# 1003          298 Drugs Driveway           None    None
# 1004            980 Paper Avenue   Pennsylvania   18503
# 1005            123 Dragons Road           None    None
# 1006            768 City Parkway           None    None
# 1007           1209 South Street           None    None
# 1008               98 Clue Drive           None    None
# 1009            123 Middle Earth           None    None
# 1010            25th Main Street       New York    None
# 1011              612 Shire Lane          Shire    None
# 1012        2394 Hogwarts Avenue           None    None
# 1013            2039 Main Street           None    None
# 1014            343 City Parkway           None    None
# 1015               214 HR Avenue           None    None
# 1016        2395 Hogwarts Avenue           None    None
# ...

# %%
df[['street_Address','state','Zip_code']]=df['Address'].str.split(pat=',', n=2, expand=True)
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123-643-9775
# 1003           Walter       White  706-695-0392
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876-678-3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf         NaN
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee
# 1012            Harry      Potter  706-695-0392
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent  706-695-0392
# 1019            Creed      Braton
# ...

# %%
df['Paying Customer'].set.replace('Y','Yes',regex=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2942/3277962175.py in <cell line: 0>()
# ----> 1 df['Paying Customer'].set.replace('Y','Yes',regex=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'set'
